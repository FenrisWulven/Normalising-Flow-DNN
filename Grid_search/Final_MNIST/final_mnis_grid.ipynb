# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# Metrics and hyperparameters
    #accuracy,brier_score,confidence_APR_aleatoric,confidence_APR_epistemic,confidence_AUROC_aleatoric,confidence_AUROC_epistemic,
    # entropy_aleatoric,entropy_epistemic,ood_detection_APR_aleatoric_FashionMNIST,ood_detection_APR_epistemic_FashionMNIST,
    # ood_detection_AUROC_aleatoric_FashionMNIST,ood_detection_AUROC_epistemic_FashionMNIST,entropy_aleatoric_FashionMNIST,
    # entropy_epistemic_FashionMNIST,ood_detection_APR_aleatoric_KMNIST,ood_detection_APR_epistemic_KMNIST,
    # ood_detection_AUROC_aleatoric_KMNIST,ood_detection_AUROC_epistemic_KMNIST,entropy_aleatoric_KMNIST,entropy_epistemic_KMNIST
metrics = ['accuracy', 'brier_score', 'confidence_APR_aleatoric', 'confidence_APR_epistemic', 'ood_detection_APR_aleatoric_FashionMNIST', 
           'ood_detection_APR_epistemic_FashionMNIST', 'ood_detection_APR_aleatoric_KMNIST', 'ood_detection_APR_epistemic_KMNIST']
flows = [6] #['4', '6', '8', '10', '20']
learning_rates = ['LR0.001', 'LR0.0001', 'LR1e-05']
regularization_strengths = ['Reg0', 'Reg0.0001', 'Reg1e-05', ]
#regularization_strengths = ['Reg0', 'Reg0.001', 'Reg0.0001', 'Reg1e-05', 'Reg5e-05', 'Reg5e-06']

# Initialize dictionary for results
results_dict = {flow: {metric: pd.DataFrame(index=regularization_strengths, columns=learning_rates, data=0.0) for metric in metrics} for flow in flows}

# Directory with CSV files
path = '.'

# Process CSV files
file_names = [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f)) and f.endswith('.csv')]
for flow in flows:
    for file_name in file_names:
        if f'Flows{flow}' in file_name:
            # Extract LR and Reg from file name
            parts = file_name.split('_')
            lr_part = [part for part in parts if part.startswith('LR')][0]
            reg_part = [part for part in parts if part.startswith('Reg')][0]
            lr_value = 'LR' + lr_part[2:]
            reg_value = 'Reg' + reg_part[3:]

            # Read data and update the corresponding DataFrame
            if lr_value in learning_rates and reg_value in regularization_strengths:
                df = pd.read_csv(file_name)
                for metric in metrics:
                    results_dict[flow][metric].loc[reg_value, lr_value] = df[metric].item()

# print how many csv files were processed
print(f"Processed {len(file_names)} files")
# print the 

# Visualization
for flow, metrics_dict in results_dict.items():
    # only show flow 6
    # if flow != '':
    #     continue
    for metric, df in metrics_dict.items():
        latex_table = df.to_latex(float_format="%.6f", header=True, bold_rows=True)
        latex_table = latex_table.replace("\\toprule", f"\\toprule\n{{\\textbf{{{metric.title()}}}}} & \\multicolumn{{3}}{{c}}{{\\textbf{{Learning Rates}}}} \\\\")
        #
        # print(f"Results for Flow {flow}, Metric: {metric}")
        print(latex_table)
# Out:
# Processed 9 files
# \begin{tabular}{lrrr}
# \toprule
# {\textbf{Accuracy}} & \multicolumn{3}{c}{\textbf{Learning Rates}} \\
# {} &  LR0.001 &  LR0.0001 &  LR1e-05 \\
# \midrule
# \textbf{Reg0     } & 0.954083 &  0.957500 & 0.751750 \\
# \textbf{Reg0.0001} & 0.975333 &  0.949833 & 0.839333 \\
# \textbf{Reg1e-05 } & 0.973750 &  0.953000 & 0.752083 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{lrrr}
# \toprule
# {\textbf{Brier_Score}} & \multicolumn{3}{c}{\textbf{Learning Rates}} \\
# {} &  LR0.001 &  LR0.0001 &  LR1e-05 \\
# \midrule
# \textbf{Reg0     } & 0.134122 &  0.102446 & 0.544587 \\
# \textbf{Reg0.0001} & 0.066329 &  0.114910 & 0.328743 \\
# \textbf{Reg1e-05 } & 0.067842 &  0.109903 & 0.544673 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{lrrr}
# \toprule
# {\textbf{Confidence_Apr_Aleatoric}} & \multicolumn{3}{c}{\textbf{Learning Rates}} \\
# {} &  LR0.001 &  LR0.0001 &  LR1e-05 \\
# \midrule
# \textbf{Reg0     } & 0.996132 &  0.995698 & 0.941425 \\
# \textbf{Reg0.0001} & 0.998679 &  0.994994 & 0.980008 \\
# \textbf{Reg1e-05 } & 0.998312 &  0.995653 & 0.941147 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{lrrr}
# \toprule
# {\textbf{Confidence_Apr_Epistemic}} & \multicolumn{3}{c}{\textbf{Learning Rates}} \\
# {} &  LR0.001 &  LR0.0001 &  LR1e-05 \\
# \midrule
# \textbf{Reg0     } & 0.989924 &  0.992704 & 0.919228 \\
# \textbf{Reg0.0001} & 0.995315 &  0.991001 & 0.962959 \\
# \textbf{Reg1e-05 } & 0.995139 &  0.992204 & 0.918854 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{lrrr}
# \toprule
# {\textbf{Ood_Detection_Apr_Aleatoric_Fashionmnist}} & \multicolumn{3}{c}{\textbf{Learning Rates}} \\
# {} &  LR0.001 &  LR0.0001 &  LR1e-05 \\
# \midrule
# \textbf{Reg0     } & 0.945112 &  0.984945 & 0.879577 \\
# \textbf{Reg0.0001} & 0.976946 &  0.983839 & 0.937844 \\
# \textbf{Reg1e-05 } & 0.973301 &  0.984576 & 0.878612 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{lrrr}
# \toprule
# {\textbf{Ood_Detection_Apr_Epistemic_Fashionmnist}} & \multicolumn{3}{c}{\textbf{Learning Rates}} \\
# {} &  LR0.001 &  LR0.0001 &  LR1e-05 \\
# \midrule
# \textbf{Reg0     } & 0.929596 &  0.990022 & 0.872073 \\
# \textbf{Reg0.0001} & 0.982140 &  0.986603 & 0.921320 \\
# \textbf{Reg1e-05 } & 0.979904 &  0.987234 & 0.871178 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{lrrr}
# \toprule
# {\textbf{Ood_Detection_Apr_Aleatoric_Kmnist}} & \multicolumn{3}{c}{\textbf{Learning Rates}} \\
# {} &  LR0.001 &  LR0.0001 &  LR1e-05 \\
# \midrule
# \textbf{Reg0     } & 0.949846 &  0.966056 & 0.917831 \\
# \textbf{Reg0.0001} & 0.955553 &  0.968826 & 0.938200 \\
# \textbf{Reg1e-05 } & 0.977406 &  0.964567 & 0.918071 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{lrrr}
# \toprule
# {\textbf{Ood_Detection_Apr_Epistemic_Kmnist}} & \multicolumn{3}{c}{\textbf{Learning Rates}} \\
# {} &  LR0.001 &  LR0.0001 &  LR1e-05 \\
# \midrule
# \textbf{Reg0     } & 0.952019 &  0.967329 & 0.916478 \\
# \textbf{Reg0.0001} & 0.955288 &  0.968696 & 0.939097 \\
# \textbf{Reg1e-05 } & 0.980155 &  0.962886 & 0.916818 \\
# \bottomrule
# \end{tabular}
# C:\Users\ollie\AppData\Local\Temp\ipykernel_1580\1826009827.py:53: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   latex_table = df.to_latex(float_format="%.6f", header=True, bold_rows=True)
